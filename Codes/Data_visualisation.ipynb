# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
path2  = '/CSV Files/'
path = os.path.dirname(os.getcwd())

# %%
pokemon = pd.read_csv(path + path2 +'pokemon_data.csv')
combats = pd.read_csv(path + path2 +'combats.csv')

# %%
print("The pokemon stats information :")
pokemon
# Out:
# The pokemon stats information :
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
print("The combat result of two pokemons :")
combats
# Out:
# The combat result of two pokemons :
#        First_pokemon  Second_pokemon  Winner
# 0                266             298     298
# 1                702             701     701
# 2                191             668     668
# 3                237             683     683
# 4                151             231     151
# ...              ...             ...     ...
# 49995            707             126     707
# 49996            589             664     589
# 49997            303             368     368
# 49998            109              89     109
# 49999              9              73       9
#
# [50000 rows x 3 columns]

# %%
types = pokemon['Type 1'].unique()

# %%
print("The diffrent types of pokemon are :")
types
# Out:
# The diffrent types of pokemon are :
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
type_sum = pokemon['Type 1'].value_counts() + pokemon['Type 2'].dropna().value_counts()
type_sum
# Out:
# Bug          72
# Dark         51
# Dragon       50
# Electric     50
# Fairy        40
# Fighting     53
# Fire         64
# Flying      101
# Ghost        46
# Grass        95
# Ground       67
# Ice          38
# Normal      102
# Poison       62
# Psychic      90
# Rock         58
# Steel        49
# Water       126
# Name: count, dtype: int64

# %%
bright_colors = [
    '#FF0000',  # Red
    '#FFA500',  # Orange
    '#FFFF00',  # Yellow
    '#00FF00',  # Lime
    '#00FFFF',  # Cyan
    '#0000FF',  # Blue
    '#800080',  # Purple
    '#FF1493',  # Deep Pink
    '#FFD700',  # Gold
    '#32CD32',  # Lime Green
    '#00CED1',  # Dark Turquoise
    '#9370DB',  # Medium Purple
    '#DC143C',  # Crimson
    '#48D1CC',  # Medium Turquoise
    '#FF6347',  # Tomato
    '#FF4500',  # Orange Red
    '#8A2BE2',  # Blue Violet
    '#00FF7F'   # Spring Green
]

# %%
fig, ax = plt.subplots(figsize=(16, 6))
plt.bar(types, type_sum, color=bright_colors)

# Add labels and title
plt.xlabel('Types')
plt.ylabel('Type Count')
plt.title('Pokemon Types with their values')

# Display the bar graph
plt.show()

# %%
pokemon
# Out:
#        #            Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0      1       Bulbasaur    Grass  Poison  45      49       49       65
# 1      2         Ivysaur    Grass  Poison  60      62       63       80
# 2      3        Venusaur    Grass  Poison  80      82       83      100
# 3      4   Mega Venusaur    Grass  Poison  80     100      123      122
# 4      5      Charmander     Fire     NaN  39      52       43       60
# ..   ...             ...      ...     ...  ..     ...      ...      ...
# 795  796         Diancie     Rock   Fairy  50     100      150      100
# 796  797    Mega Diancie     Rock   Fairy  50     160      110      160
# 797  798  Hoopa Confined  Psychic   Ghost  80     110       60      150
# 798  799   Hoopa Unbound  Psychic    Dark  80     160       60      170
# 799  800       Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 0         65     45           1      False
# ...

# %%
HP = pokemon['HP']
# Create a histogram
plt.hist(HP, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('HP')

# Display the histogram
plt.show()

# %%
attack = pokemon['Attack']
# Create a histogram
plt.hist(attack, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Attack')

# Display the histogram
plt.show()

# %%
defence = pokemon['Defense']
# Create a histogram
plt.hist(defence, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Defence')

# Display the histogram
plt.show()

# %%
pokemon.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
Sp_attack = pokemon['Sp. Atk']
# Create a histogram
plt.hist(Sp_attack, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Sp. Attack')

# Display the histogram
plt.show()

# %%
Sp_attack = pokemon['Sp. Def']
# Create a histogram
plt.hist(Sp_attack, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Sp. defence')

# Display the histogram
plt.show()

# %%
Sp_attack = pokemon['Speed']
# Create a histogram
plt.hist(Sp_attack, bins=30, color='blue', edgecolor='black')

# Add labels and title
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Speed')

# Display the histogram
plt.show()
